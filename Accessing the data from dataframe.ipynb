# %% [markdown]
# ## accessing the data from dataframe

# %%
# accessing the data from the dataframe

# %%
import numpy as np
import pandas as pd

# %%
# read the data from csv file 
df=pd.read_csv("C:\\Users\\dell\\pandas\\studentmarks1.csv")
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
# get first 5 records of dataframe by using the head()
df.head()
# Out:
#    htno    name  telugu  english  hindi  maths  science  social
# 0   100  Ramesh      50       60     66     98       66      55
# 1   101  Rajesh      45       67     34     67       66      78
# 2   102  Rossum      56       88     56     99       44      77
# 3   103    Raji      56       78     34     56       88      55
# 4   104  Kalyan      51       63     62     93       67      51

# %%
# get first 3 records from the dataframe by using the head()
df.head(3)
# Out:
#    htno    name  telugu  english  hindi  maths  science  social
# 0   100  Ramesh      50       60     66     98       66      55
# 1   101  Rajesh      45       67     34     67       66      78
# 2   102  Rossum      56       88     56     99       44      77

# %%
# get first 6 record from dataframe by using the head()
df.head(6)
# Out:
#    htno     name  telugu  english  hindi  maths  science  social
# 0   100   Ramesh      50       60     66     98       66      55
# 1   101   Rajesh      45       67     34     67       66      78
# 2   102   Rossum      56       88     56     99       44      77
# 3   103     Raji      56       78     34     56       88      55
# 4   104   Kalyan      51       63     62     93       67      51
# 5   105  Karthik      48       62     39     68       65      88

# %%
# get the last 5 records from the dataframe by using the tail()
df.tail()
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67
# 14   113     sonu      60       89     98     87       77      68
# 15   114   Rajesh      45       67     77     55       66      46
# 16   115   Rakesh      67       78     88     78       67      49

# %%
# get last 3 records from the dataframe by using tail()
df.tail(3)
# Out:
#     htno    name  telugu  english  hindi  maths  science  social
# 14   113    sonu      60       89     98     87       77      68
# 15   114  Rajesh      45       67     77     55       66      46
# 16   115  Rakesh      67       78     88     78       67      49

# %%
# get last 6 records from the dataframe by using tail()
df.tail(6)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67
# 14   113     sonu      60       89     98     87       77      68
# 15   114   Rajesh      45       67     77     55       66      46
# 16   115   Rakesh      67       78     88     78       67      49

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x00000225EA1008C0>

# %%
for val in df.iterrows():
    print(val)
    print("-"*50)
# Out:
# (0, htno          100
# name       Ramesh
# telugu         50
# english        60
# hindi          66
# maths          98
# science        66
# social         55
# Name: 0, dtype: object)
# --------------------------------------------------
# (1, htno          101
# name       Rajesh
# telugu         45
# english        67
# hindi          34
# maths          67
# science        66
# social         78
# Name: 1, dtype: object)
# --------------------------------------------------
# (2, htno          102
# name       Rossum
# telugu         56
# english        88
# hindi          56
# maths          99
# science        44
# social         77
# Name: 2, dtype: object)
# --------------------------------------------------
# (3, htno        103
# name       Raji
# telugu       56
# english      78
# hindi        34
# maths        56
# science      88
# social       55
# Name: 3, dtype: object)
# --------------------------------------------------
# (4, htno          104
# name       Kalyan
# ...

# %%
df.shape
# Out:
# (17, 8)

# %%
print("number of rows=",df.shape[0])
print("number of columns=",df.shape[1])
# Out:
# number of rows= 17
# number of columns= 8

# %%
df.describe()
# Out:
#              htno     telugu    english      hindi      maths    science  \
# count   17.000000  17.000000  17.000000  17.000000  17.000000  17.000000
# mean   107.294118  54.000000  70.705882  65.764706  82.235294  69.588235
# std      4.687279   7.141428  11.671358  20.504662  13.917298  14.339887
# min    100.000000  45.000000  48.000000  34.000000  55.000000  44.000000
# 25%    104.000000  50.000000  63.000000  56.000000  76.000000  66.000000
# 50%    107.000000  53.000000  67.000000  64.000000  87.000000  67.000000
# 75%    111.000000  56.000000  78.000000  77.000000  93.000000  77.000000
# max    115.000000  67.000000  89.000000  99.000000  99.000000  98.000000
#
#           social
# count  17.000000
# mean   59.882353
# std    14.696438
# min    35.000000
# 25%    49.000000
# 50%    55.000000
# 75%    73.000000
# max    88.000000

# %%
# describe() is giving the the some stastical information about the dataframe

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
# get the 7 th row from the dataframe by using [start:stop:step]
df[7:8]
# Out:
#    htno     name  telugu  english  hindi  maths  science  social
# 7   107  Praveen      46       88     74     86       78      45

# %%
# get the 12 th row from the dataframe by using [start:stop:step]
df[12:13]
# Out:
#     htno    name  telugu  english  hindi  maths  science  social
# 12   104  Kalyan      51       63     62     93       67      51

# %%
# get the number of rows 
df[10:17]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67
# 14   113     sonu      60       89     98     87       77      68
# 15   114   Rajesh      45       67     77     55       66      46
# 16   115   Rakesh      67       78     88     78       67      49

# %%
# get the 8 to last row
df[8:]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67
# 14   113     sonu      60       89     98     87       77      68
# 15   114   Rajesh      45       67     77     55       66      46
# 16   115   Rakesh      67       78     88     78       67      49

# %%
df[11:20]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67
# 14   113     sonu      60       89     98     87       77      68
# 15   114   Rajesh      45       67     77     55       66      46
# 16   115   Rakesh      67       78     88     78       67      49

# %%
# get the alternative rows 
df[::2]
# Out:
#     htno    name  telugu  english  hindi  maths  science  social
# 0    100  Ramesh      50       60     66     98       66      55
# 2    102  Rossum      56       88     56     99       44      77
# 4    104  Kalyan      51       63     62     93       67      51
# 6    106  Kambli      53       81     59     92       48      73
# 8    108  Ganesh      53       62     76     88       76      35
# 10   110   Biswa      66       48     86     95       48      47
# 12   104  Kalyan      51       63     62     93       67      51
# 14   113    sonu      60       89     98     87       77      68
# 16   115  Rakesh      67       78     88     78       67      49

# %%
# get the alternative rows from the index 1 
df[1::2]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 1    101   Rajesh      45       67     34     67       66      78
# 3    103     Raji      56       78     34     56       88      55
# 5    105  Karthik      48       62     39     68       65      88
# 7    107  Praveen      46       88     74     86       78      45
# 9    109     Nags      55       77     44     77       86      58
# 11   111   Ritchi      66       68     64     76       98      75
# 13   112  shareef      50       63     99     90       76      67
# 15   114   Rajesh      45       67     77     55       66      46

# %%
# get the column-->name
df["name"]
# Out:
# 0      Ramesh
# 1      Rajesh
# 2      Rossum
# 3        Raji
# 4      Kalyan
# 5     Karthik
# 6      Kambli
# 7     Praveen
# 8      Ganesh
# 9        Nags
# 10      Biswa
# 11     Ritchi
# 12     Kalyan
# 13    shareef
# 14       sonu
# 15     Rajesh
# 16     Rakesh
# Name: name, dtype: object

# %%
# get the column maths
df["maths"]
# Out:
# 0     98
# 1     67
# 2     99
# 3     56
# 4     93
# 5     68
# 6     92
# 7     86
# 8     88
# 9     77
# 10    95
# 11    76
# 12    93
# 13    90
# 14    87
# 15    55
# 16    78
# Name: maths, dtype: int64

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
# get the multiple columns like name ,science marks and social marks
df[["name","science","social"]]
# Out:
#        name  science  social
# 0    Ramesh       66      55
# 1    Rajesh       66      78
# 2    Rossum       44      77
# 3      Raji       88      55
# 4    Kalyan       67      51
# 5   Karthik       65      88
# 6    Kambli       48      73
# 7   Praveen       78      45
# 8    Ganesh       76      35
# 9      Nags       86      58
# 10    Biswa       48      47
# 11   Ritchi       98      75
# 12   Kalyan       67      51
# 13  shareef       76      67
# 14     sonu       77      68
# 15   Rajesh       66      46
# 16   Rakesh       67      49

# %%
# get the all marks columns
df[["telugu","english","hindi","maths","science","social"]]
# Out:
#     telugu  english  hindi  maths  science  social
# 0       50       60     66     98       66      55
# 1       45       67     34     67       66      78
# 2       56       88     56     99       44      77
# 3       56       78     34     56       88      55
# 4       51       63     62     93       67      51
# 5       48       62     39     68       65      88
# 6       53       81     59     92       48      73
# 7       46       88     74     86       78      45
# 8       53       62     76     88       76      35
# 9       55       77     44     77       86      58
# 10      66       48     86     95       48      47
# 11      66       68     64     76       98      75
# 12      51       63     62     93       67      51
# 13      50       63     99     90       76      67
# 14      60       89     98     87       77      68
# 15      45       67     77     55       66      46
# 16      67       78     88     78       67      49

# %%
# get the specified rows and specified columns
df[0:11][["name","htno","maths"]]
# Out:
#        name  htno  maths
# 0    Ramesh   100     98
# 1    Rajesh   101     67
# 2    Rossum   102     99
# 3      Raji   103     56
# 4    Kalyan   104     93
# 5   Karthik   105     68
# 6    Kambli   106     92
# 7   Praveen   107     86
# 8    Ganesh   108     88
# 9      Nags   109     77
# 10    Biswa   110     95

# %%
print(df[df["maths"]>75])
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 2    102   Rossum      56       88     56     99       44      77
# 4    104   Kalyan      51       63     62     93       67      51
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# 13   112  shareef      50       63     99     90       76      67
# 14   113     sonu      60       89     98     87       77      68
# 16   115   Rakesh      67       78     88     78       67      49

# %%
df[1:4]
# Out:
#    htno    name  telugu  english  hindi  maths  science  social
# 1   101  Rajesh      45       67     34     67       66      78
# 2   102  Rossum      56       88     56     99       44      77
# 3   103    Raji      56       78     34     56       88      55

# %%
df[::]
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
df[1:6]["name"]
# Out:
# 1     Rajesh
# 2     Rossum
# 3       Raji
# 4     Kalyan
# 5    Karthik
# Name: name, dtype: object

# %%
df[12:16]["science"]
# Out:
# 12    67
# 13    76
# 14    77
# 15    66
# Name: science, dtype: int64

# %%
df[10:17][["science","social"]]
# Out:
#     science  social
# 10       48      47
# 11       98      75
# 12       67      51
# 13       76      67
# 14       77      68
# 15       66      46
# 16       67      49

# %%
print(df)
# Out:
#     htno     name  telugu  english  hindi  maths  science  social
# 0    100   Ramesh      50       60     66     98       66      55
# 1    101   Rajesh      45       67     34     67       66      78
# 2    102   Rossum      56       88     56     99       44      77
# 3    103     Raji      56       78     34     56       88      55
# 4    104   Kalyan      51       63     62     93       67      51
# 5    105  Karthik      48       62     39     68       65      88
# 6    106   Kambli      53       81     59     92       48      73
# 7    107  Praveen      46       88     74     86       78      45
# 8    108   Ganesh      53       62     76     88       76      35
# 9    109     Nags      55       77     44     77       86      58
# 10   110    Biswa      66       48     86     95       48      47
# 11   111   Ritchi      66       68     64     76       98      75
# 12   104   Kalyan      51       63     62     93       67      51
# ...

# %%
df["htno"]
# Out:
# 0     100
# 1     101
# 2     102
# 3     103
# 4     104
# 5     105
# 6     106
# 7     107
# 8     108
# 9     109
# 10    110
# 11    111
# 12    104
# 13    112
# 14    113
# 15    114
# 16    115
# Name: htno, dtype: int64

# %%
df["name"]
# Out:
# 0      Ramesh
# 1      Rajesh
# 2      Rossum
# 3        Raji
# 4      Kalyan
# 5     Karthik
# 6      Kambli
# 7     Praveen
# 8      Ganesh
# 9        Nags
# 10      Biswa
# 11     Ritchi
# 12     Kalyan
# 13    shareef
# 14       sonu
# 15     Rajesh
# 16     Rakesh
# Name: name, dtype: object

# %%
df[["name","htno","telugu"]]
# Out:
#        name  htno  telugu
# 0    Ramesh   100      50
# 1    Rajesh   101      45
# 2    Rossum   102      56
# 3      Raji   103      56
# 4    Kalyan   104      51
# 5   Karthik   105      48
# 6    Kambli   106      53
# 7   Praveen   107      46
# 8    Ganesh   108      53
# 9      Nags   109      55
# 10    Biswa   110      66
# 11   Ritchi   111      66
# 12   Kalyan   104      51
# 13  shareef   112      50
# 14     sonu   113      60
# 15   Rajesh   114      45
# 16   Rakesh   115      67

# %%
df[["name","english"]][12:14]
# Out:
#        name  english
# 12   Kalyan       63
# 13  shareef       63

# %%
df[["name","telugu","english","hindi"]][::2]
# Out:
#       name  telugu  english  hindi
# 0   Ramesh      50       60     66
# 2   Rossum      56       88     56
# 4   Kalyan      51       63     62
# 6   Kambli      53       81     59
# 8   Ganesh      53       62     76
# 10   Biswa      66       48     86
# 12  Kalyan      51       63     62
# 14    sonu      60       89     98
# 16  Rakesh      67       78     88
